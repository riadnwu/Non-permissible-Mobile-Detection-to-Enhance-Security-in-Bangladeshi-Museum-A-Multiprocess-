# %%
# !nvidia-smi
# Out:
# Mon Sep 18 17:20:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
# %cd /content/drive/MyDrive/Camera Detection
# Out:
# /content/drive/.shortcut-targets-by-id/15vaTC92h0GxQRPCGPOJlqOsBBmRRUqrI/Camera Detection

# %%
# !ls
# Out:
# all_fold		       fold_0.yaml			    runs
# camera_detection.ipynb	       fold_1_camera_detection.ipynb	    video
# data			       fold_1.yaml			    yolov8n.pt
# data.yaml		       process_data
# fold_0_camera_detection.ipynb  process_data_camera_detection.ipynb

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=fold_1.yaml epochs=20 plots=True
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
