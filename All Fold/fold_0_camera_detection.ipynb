# %%
# !nvidia-smi
# Out:
# Mon Sep 18 13:48:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.1/617.1 kB 9.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Camera Detection
# Out:
# /content/drive/MyDrive/Camera Detection

# %%
# !ls
# Out:
#  all_fold			 fold_4.yaml
#  camera_detection.ipynb		 process_data
#  data				 process_data_camera_detection.ipynb
#  data.yaml			 runs
#  fold_0_camera_detection.ipynb	 video
#  fold_0.yaml			'yolov5 train data'
#  fold_4_camera_detection.ipynb	 yolov8n.pt

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=fold_0.yaml epochs=20 plots=True
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
